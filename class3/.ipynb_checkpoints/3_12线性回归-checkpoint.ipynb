# %%
# %matplotlib inline
import math
import time
import numpy as np
import torch
from d2l import torch as d2l

# %% [markdown]
# ## 矢量化的高效操作
# ### 定义计时函数

# %%
class Timer: #@save
    """记录多次运⾏时间"""
    def __init__(self):
        self.times = []
        self.start()
    def start(self):
        """启动计时器"""
        self.tik = time.time()
    def stop(self):
        """停⽌计时器并将时间记录在列表中"""
        self.times.append(time.time() - self.tik)
        return self.times[-1]
    def avg(self):
        """返回平均时间"""
        return sum(self.times) / len(self.times)
    def sum(self):
        """返回时间总和"""
        return sum(self.times)
    def cumsum(self):
        """返回累计时间"""
        return np.array(self.times).cumsum().tolist()

# %%
n = 10000
a = torch.ones(n)
b = torch.ones(n)

# %%
c = torch.zeros(n)
timer = Timer()
for i in range(n):
    c[i] = a[i] + b[i]
c, f'{timer.stop():.5f} sec'
# Out:
# (tensor([2., 2., 2.,  ..., 2., 2., 2.]), '0.05500 sec')

# %%
timer.start()
d = a + b
d, f'{timer.stop():.10f} sec'
# Out:
# (tensor([2., 2., 2.,  ..., 2., 2., 2.]), '0.0000000000 sec')

# %% [markdown]
# ### 由上可见，⽮量化代码通常会带来数量级的加速

# %% [markdown]
# ## 高斯分布
# ![image.png](attachment:2437842e-2d02-41de-a1fa-279f5497004f.png)

# %%
def normal(x, mu, sigma):
    p = 1 / math.sqrt(2 * math.pi * sigma**2)
    return p * np.exp(-0.5 * (x - mu)**2 / sigma**2)

# %% [markdown]
# ### math.sqrt()表示开根号，np.exp表示e的幂函数

# %%
# 再次使⽤numpy进⾏可视化
x = np.arange(-7, 7, 0.01)
# 均值和标准差对
params = [(0, 1), (0, 2), (3, 1)]
d2l.plot(x, [normal(x, mu, sigma) for mu, sigma in params], xlabel='x',
        ylabel='p(x)', figsize=(4.5, 2.5),
        legend=[f'mean {mu}, std {sigma}' for mu, sigma in params])

# %% [markdown]
# # 线性回归从零实现

# %%
# %matplotlib inline
import random
import torch
from d2l import torch as d2l

# %% [markdown]
# ## 生成人造数据
# ###                ![image.png](attachment:498f214a-f677-4b4b-a976-e48e10145415.png)

# %% [markdown]
# ### X生成的为均值=0，方差=1，尺寸为(num_examples,len(w))
# ### 在倒数第二行那里，加入噪音操作中normal第三个位置就是该数据的性状设定
# ### 最后将y作为列向量返回

# %% [markdown]
# ### 对于matmul函数与mm与mv：两个张量均为1维张量时，计算向量的内积
# ### 两个张量均为2维张量（即矩阵）时，计算矩阵的乘法
# ### 第一个向量为1维张量，第二个张量为2维张量，对第一个张量变成二维行向量，然后进行矩阵乘法
# ### 第二个向量为1维张量，第一个张量为2维张量，计算矩阵和向量的乘法；

# %%
def synthetic_data(w, b, num_examples): #@save
    """⽣成y=Xw+b+噪声"""
    X = torch.normal(0, 1, (num_examples, len(w)))
    y = torch.matmul(X, w) + b
    y += torch.normal(0, 0.01, y.shape)
    return X, y.reshape((-1, 1))

# %% [markdown]
# ### 设w为二维，则x也应为2维，数据造1000个样本

# %%
true_w = torch.tensor([2, -3.4])
true_b = 4.2
features, labels = synthetic_data(true_w, true_b, 1000)
true_w.shape, features.shape, labels.shape
# Out:
# (torch.Size([2]), torch.Size([1000, 2]), torch.Size([1000, 1]))

# %% [markdown]
# ### 如果是labels[0][0]，索引出来就是单独的7.1709这个值
# ### labels[0]索引出来的尺寸为([1]),单独标量是没有size的

# %%
print('features:', features[0],'\nlabel:', labels[0])
# Out:
# features: tensor([ 1.1839, -0.1766])
# label: tensor([7.1709])

# %% [markdown]
# ### 通过⽣成第⼆个特征features[:, 1]和labels的散点图，可以直观观察到两者之间的线性关系
# ### 这里detach是有的torch向量中必须分离出计算图才能送到numpy中

# %%
d2l.set_figsize()
d2l.plt.scatter(features[:, (1)].detach().numpy(), labels.detach().numpy(), 1);

# %% [markdown]
# ## 读取数据集

# %% [markdown]
# ### 由于训练时每次抽取小批量便利，所以要指定一个输入小批量数据的函数

# %% [markdown]
# ### 输入bs，特征向量，类别向量
# ### 首先生成一个index，features是1000×2的矩阵，len()是取其第一维度的大小！
# ### yeild就是return返回一个值，并记住这个返回的位置，下次迭代就从这个位置之后开始
# ### for循环中，从0开始，一直到num_example，每次隔bs抽一次i
# ### 下面这个小demo中，展示了每次取一个bs，最后如果取不到就取到最后一个
# ### 其中先生成一个表格，tensor里面是对表格进行切片

# %%
# indices1 = list(range(11))
# for i in range(0, 11, 3):
#     g = torch.tensor(indices1[i: min(i + 3, 11)])
#     print(g, i)
# Out:
# tensor([0, 1, 2]) 0
# tensor([3, 4, 5]) 3
# tensor([6, 7, 8]) 6
# tensor([ 9, 10]) 9

# %%
# demoo = list(range(3))
# torch.tensor(demoo[0: 3])
# Out:
# tensor([0, 1, 2])

# %% [markdown]
# ### 当i=80时，bi输出的是一个(10,)的张量,里面的数字打乱顺序tensor([349, 762...]
# ### 此时features是一个(1000,2),labels(1000,1)
# ### features[bi]输出根据bi索引位置对应的10个(10,2)的张量，labels[bi]为对应位置10个(10,1)张量
# ### 也就是对于(a,b)的张量A，索引A[a]中，a为尺寸为(c)tensor，即可索引c个原A张量中分别对应每个ci的元素

# %%
def data_iter(batch_size, features, labels):
    num_examples = len(features)
    indices = list(range(num_examples))
    # 这些样本是随机读取的，没有特定的顺序
    random.shuffle(indices)
    for i in range(0, num_examples, batch_size):
        batch_indices = torch.tensor(
            indices[i: min(i + batch_size, num_examples)])
        yield features[batch_indices], labels[batch_indices]

batch_size = 10
for X, y in data_iter(batch_size, features, labels):
    print(X, '\n', y)
    break
# Out:
# tensor([[ 0.5959, -1.6581],
#         [ 0.3982,  1.7281],
#         [ 1.1094, -1.7265],
#         [-0.3012, -1.0192],
#         [-1.7998, -0.7025],
#         [ 0.3708,  0.6183],
#         [ 1.3523, -0.1823],
#         [ 0.7591,  0.1995],
#         [-0.0750, -0.5252],
#         [-0.5210, -2.4143]])
#  tensor([[11.0278],
#         [-0.8752],
#         [12.2801],
#         [ 7.0519],
#         [ 2.9824],
#         [ 2.8345],
#         [ 7.5145],
#         [ 5.0382],
#         [ 5.8434],
#         [11.3820]])

# %% [markdown]
# ### 初始化参数
# ### w为均值=0，标准差=0.01的正态分布中采样随机数，b=0

# %%
w = torch.normal(0, 0.01, size=(2,1), requires_grad=True)
b = torch.zeros(1, requires_grad=True)

# %% [markdown]
# ### 定义模型

# %%
def linreg(X, w, b): #@save
    """线性回归模型"""
    return torch.matmul(X, w) + b

# %%
def squared_loss(y_hat, y): #@save
    """均⽅损失"""
    return (y_hat - y.reshape(y_hat.shape)) ** 2 / 2

# %% [markdown]
# ### params里面包含了w与b；在更新时不用计算梯度；
# ### 在损失函数除bs与在此除bs一样的；别忘了最后梯度要清零

# %%
def sgd(params, lr, batch_size): #@save
    """⼩批量随机梯度下降"""
    with torch.no_grad():
        for param in params:
            param -= lr * param.grad / batch_size
            param.grad.zero_()

# %%
lr = 0.03
num_epochs = 3
net = linreg
loss = squared_loss

# %%
for epoch in range(num_epochs):
    for X, y in data_iter(batch_size, features, labels):
        l = loss(net(X, w, b), y) # X和y的⼩批量损失
        # 因为l形状是(batch_size,1)，⽽不是⼀个标量。l中的所有元素被加到⼀起，
        # 并以此计算关于[w,b]的梯度
        l.sum().backward()
        sgd([w, b], lr, batch_size) # 使⽤参数的梯度更新参数
    with torch.no_grad():
        train_l = loss(net(features, w, b), labels)
        print(f'epoch {epoch + 1}, loss {float(train_l.mean()):f}')
# Out:
# epoch 1, loss 0.033643
# epoch 2, loss 0.000137
# epoch 3, loss 0.000049

# %%
print(f'w的估计误差: {true_w - w.reshape(true_w.shape)}')
print(f'b的估计误差: {true_b - b}')
# Out:
# w的估计误差: tensor([0.0007, 0.0004], grad_fn=<SubBackward0>)
# b的估计误差: tensor([0.0008], grad_fn=<RsubBackward1>)
